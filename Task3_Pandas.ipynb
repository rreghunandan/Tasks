# %% [markdown]
# <a href="https://colab.research.google.com/github/rreghunandan/Tasks/blob/main/Task3_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd._version
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 66e3805b8cabe977f40c05259cc3fcf7ead5687d
# python           : 3.7.12.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 5.4.144+
# Version          : #1 SMP Tue Dec 7 09:58:10 PST 2021
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : None
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.3.5
# numpy            : 1.21.5
# pytz             : 2018.9
# dateutil         : 2.8.2
# pip              : 21.1.3
# setuptools       : 57.4.0
# Cython           : 0.29.27
# pytest           : 3.6.4
# hypothesis       : None
# sphinx           : 1.8.6
# blosc            : None
# feather          : 0.4.1
# xlsxwriter       : None
# lxml.etree       : 4.2.6
# html5lib         : 1.0.1
# pymysql          : None
# psycopg2         : 2.7.6.1 (dt dec pq3 ext lo64)
# jinja2           : 2.11.3
# IPython          : 5.5.0
# ...

# %%
import numpy as np

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

Labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df=pd.DataFrame(data,index=Labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df.info
# Out:
# <bound method DataFrame.info of   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no>

# %%
df.iloc[0:3]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %%
df[["animal","age"]]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %%
df.iloc[[3,4,8],[1,2]]
# Out:
#    age  visits
# d  NaN       3
# e  5.0       2
# i  7.0       2

# %%
df.loc[df.index[[3,4,8]],["animal","age"]]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %%
df[df['visits']>=3]
# Out:
#   animal  age  visits priority
# b    cat  3.0       3      yes
# d    dog  NaN       3      yes
# f    cat  2.0       3       no

# %%
df[df['age'].isnull()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
df[(df["animal"]== "cat") & (df["age"]<3)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %%
df[df["age"].between(2,4,inclusive="both")]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %%
df.loc["f","age"]=1.5

# %%
df.groupby("animal")["visits"].sum()
# Out:
# animal
# cat      8
# dog      8
# snake    3
# Name: visits, dtype: int64

# %%
df["visits"].sum()
# Out:
# 19

# %%
df.groupby("animal")["age"].mean()
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %%
df.loc["k"]=["mice",3,2,"yes"]
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no
# k   mice  3.0       2      yes

# %%
df=df.drop("k")

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df["animal"].value_counts()
# Out:
# cat      4
# dog      4
# snake    2
# Name: animal, dtype: int64

# %%
df.sort_values(by=['age', 'visits'], ascending=[False, True])
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  1.5       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %%
#df['priority'] = df['priority'].map({'yes': 1, 'no': 2})   not working

# %%
df["animal"]=df["animal"].replace("snake","python")
df
# Out:
#    animal  age  visits priority
# a     cat  2.5       1      yes
# b     cat  3.0       3      yes
# c  python  0.5       2       no
# d     dog  NaN       3      yes
# e     dog  5.0       2       no
# f     cat  1.5       3       no
# g  python  4.5       1       no
# h     cat  NaN       1      yes
# i     dog  7.0       2       no
# j     dog  3.0       1       no

# %%
df.pivot_table(index='animal', columns='visits', values='age', aggfunc='mean')
# Out:
# visits    1    2     3
# animal
# cat     2.5  NaN  2.25
# dog     3.0  6.0   NaN
# python  4.5  0.5   NaN

# %%
df.pivot_table(index='animal', columns='visits', values='age').mean()
# Out:
# visits
# 1    3.333333
# 2    3.250000
# 3    2.250000
# dtype: float64

# %%
df1 = pd.DataFrame({'A': [1, 2, 2, 3, 4, 5, 5, 5, 6, 7, 7,8,8,9]})
df1.loc[df1['A'].shift() != df1['A']]
# Out:
#     A
# 0   1
# 1   2
# 3   3
# 4   4
# 5   5
# 8   6
# 9   7
# 11  8
# 13  9

# %%
#Given a DataFrame of numeric values, say
#df = pd.DataFrame(np.random.random(size=(5, 3))) not done

# %%
df = pd.DataFrame(np.random.random(size=(5, 10)), columns=list('abcdefghij'))
df
# Out:
#           a         b         c  ...         h         i         j
# 0  0.311206  0.830453  0.344532  ...  0.605746  0.841888  0.456284
# 1  0.511480  0.877910  0.740466  ...  0.244894  0.326866  0.856373
# 2  0.662783  0.828755  0.045175  ...  0.699401  0.855734  0.937481
# 3  0.481701  0.785183  0.825240  ...  0.896736  0.519046  0.440535
# 4  0.479013  0.916120  0.275746  ...  0.907792  0.191080  0.591590
#
# [5 rows x 10 columns]

# %%
a=df.sum().min()
a
# Out:
# 2.231158313375972

# %%
df1
# Out:
#     A
# 0   1
# 1   2
# 2   2
# 3   3
# 4   4
# 5   5
# 6   5
# 7   5
# 8   6
# 9   7
# 10  7
# 11  8
# 12  8
# 13  9

# %%
a=df1.drop_duplicates(keep=False,inplace=True)
df1
# Out:
#     A
# 0   1
# 3   3
# 4   4
# 8   6
# 13  9

# %%
#You have a DataFrame that consists of 10 columns of floating--point numbers. Suppose that exactly 5 entries in each row are NaN values. 
#For each row of the DataFrame, find the column which contains the third NaN value.    not done

# %%
df = pd.DataFrame({'grps': list('aaabbcaabcccbbc'), 
                   'vals': [12,345,3,1,45,14,4,52,54,23,235,21,57,3,87]})
df
# Out:
#    grps  vals
# 0     a    12
# 1     a   345
# 2     a     3
# 3     b     1
# 4     b    45
# 5     c    14
# 6     a     4
# 7     a    52
# 8     b    54
# 9     c    23
# 10    c   235
# 11    c    21
# 12    b    57
# 13    b     3
# 14    c    87

# %%
df.groupby('grps').apply(lambda x: x.vals.nlargest(3).sum())
# Out:
# grps
# a    409
# b    156
# c    345
# dtype: int64

# %%
#A DataFrame has two integer columns 'A' and 'B'. The values in 'A' are between 1 and 100 (inclusive). 
#For each group of 10 consecutive integers in 'A' (i.e. (0, 10], (10, 20], ...), 
#calculate the sum of the corresponding values in column 'B'.    not done

# %%
#df = pd.DataFrame({'X': [7, 2, 0, 3, 4, 2, 5, 0, 3, 4]})   not done
#For each value, count the difference back to the previous zero (or the start of the Series, whichever is closer). These values should therefore be [1, 2, 0, 1, 2, 3, 4, 0, 1, 2]. Make this a new column 'Y'.

# %%
#Consider a DataFrame containing rows and columns of purely numerical data. Create a list of the row-column index locations of the 3 largest values.

# %%
data = {'Group': [11,12,1,3,10],
        'Values': [-2.5, 3, 0.5, -3,1]}

Labels = ['i', 'ii', 'iii', 'iv', 'v']
df=pd.DataFrame(data,index=Labels)
df
# Out:
#      Group  Values
# i       11    -2.5
# ii      12     3.0
# iii      1     0.5
# iv       3    -3.0
# v       10     1.0

# %%
df["Group"].mean()
# Out:
# 7.4

# %%
#Given a DataFrame with a column of group IDs, 'grps', and a column of corresponding integer values, 'vals', 
#replace any negative values in 'vals' with the group mean.noot done

# %%
#Implement a rolling mean over groups with window size 3, which ignores NaN value. For example consider the following DataFrame:   not done

# %%
d= pd.date_range(start='2015-01-01', end='2015-12-31' )
s = pd.Series(np.random.rand(len(d)),index=d)
s
# Out:
# 2015-01-01    0.098785
# 2015-01-02    0.555402
# 2015-01-03    0.719412
# 2015-01-04    0.817874
# 2015-01-05    0.190546
#                 ...
# 2015-12-27    0.349364
# 2015-12-28    0.344857
# 2015-12-29    0.848025
# 2015-12-30    0.823485
# 2015-12-31    0.736928
# Freq: D, Length: 365, dtype: float64

# %%
round(s[s.index.dayofweek == 2].sum(),2)
# Out:
# 27.36

# %%
s.resample('M').mean()
# Out:
# 2015-01-31    0.517757
# 2015-02-28    0.514175
# 2015-03-31    0.460010
# 2015-04-30    0.513605
# 2015-05-31    0.569080
# 2015-06-30    0.553647
# 2015-07-31    0.525835
# 2015-08-31    0.452178
# 2015-09-30    0.455124
# 2015-10-31    0.502303
# 2015-11-30    0.531051
# 2015-12-31    0.588206
# Freq: M, dtype: float64

# %%
df.groupby(pd.Grouper(key="4M")).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-158-acac012b20de> in <module>()
# ----> 1 df.groupby(pd.Grouper(key="4M")).mean()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7639             squeeze=squeeze,  # type: ignore[arg-type]
#    7640             observed=observed,
# -> 7641             dropna=dropna,
#    7642         )
#    7643
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     895                 observed=observed,
#     896                 mutated=self.mutated,
# --> 897                 dropna=self.dropna,
#     898             )
#     899
#
# ...

# %%
s=pd.date_range('2015-01-01', '2016-12-31', freq='WOM-3THU')
s
# Out:
# DatetimeIndex(['2015-01-15', '2015-02-19', '2015-03-19', '2015-04-16',
#                '2015-05-21', '2015-06-18', '2015-07-16', '2015-08-20',
#                '2015-09-17', '2015-10-15', '2015-11-19', '2015-12-17',
#                '2016-01-21', '2016-02-18', '2016-03-17', '2016-04-21',
#                '2016-05-19', '2016-06-16', '2016-07-21', '2016-08-18',
#                '2016-09-15', '2016-10-20', '2016-11-17', '2016-12-15'],
#               dtype='datetime64[ns]', freq='WOM-3THU')

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm', 
                               'Budapest_PaRis', 'Brussels_londOn'],
              'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
              'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
                   'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )', 
                               '12. Air France', '"Swiss Air"']})
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df['FlightNumber'] = df['FlightNumber'].interpolate().astype(int)
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %%
temp = df.From_To.str.split('_',expand=True)
temp.columns = ['From', 'To']
temp
# Out:
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
temp['From'] = temp['From'].str.capitalize()
temp['To'] = temp['To'].str.capitalize()
temp
# Out:
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %%
df = df.drop('From_To', axis=1)
df = df.join(temp)
df
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0         10045      [23, 47]               KLM(!)    London      Paris
# 1         10055            []    <Air France> (12)    Madrid      Milan
# 2         10065  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3         10075          [13]       12. Air France  Budapest      Paris
# 4         10085      [67, 32]          "Swiss Air"  Brussels     London

# %%
df['Airline'] = df['Airline'].str.extract('([a-zA-Z\s]+)', expand=False).str.strip()
df
# Out:
#    FlightNumber  RecentDelays          Airline      From         To
# 0         10045      [23, 47]              KLM    London      Paris
# 1         10055            []       Air France    Madrid      Milan
# 2         10065  [24, 43, 87]  British Airways    London  Stockholm
# 3         10075          [13]       Air France  Budapest      Paris
# 4         10085      [67, 32]        Swiss Air  Brussels     London

# %%
from operator import index
delays = df['RecentDelays'].apply(pd.Series)
delays
df = df.drop('RecentDelays', axis=1).join(delays)
df
# Out:
#    FlightNumber          Airline      From         To     0     1     2
# 0         10045              KLM    London      Paris  23.0  47.0   NaN
# 1         10055       Air France    Madrid      Milan   NaN   NaN   NaN
# 2         10065  British Airways    London  Stockholm  24.0  43.0  87.0
# 3         10075       Air France  Budapest      Paris  13.0   NaN   NaN
# 4         10085        Swiss Air  Brussels     London  67.0  32.0   NaN

# %%
letters = ['A', 'B', 'C'] 
numbers = list(range(10))
multi = pd.MultiIndex.from_product([letters, numbers], names=['letters', 'numbers'])
s = pd.Series(np.random.random(30), index=multi)
s
# Out:
# letters  numbers
# A        0          0.739254
#          1          0.400376
#          2          0.857504
#          3          0.586291
#          4          0.065819
#          5          0.531736
#          6          0.725093
#          7          0.117949
#          8          0.404746
#          9          0.571195
# B        0          0.161347
#          1          0.095436
#          2          0.349121
#          3          0.458596
#          4          0.859310
#          5          0.263086
#          6          0.266955
#          7          0.269640
#          8          0.361145
#          9          0.714692
# C        0          0.729057
#          1          0.586633
#          2          0.277516
#          3          0.921493
#          4          0.438586
#          5          0.236623
#          6          0.126660
#          7          0.136335
#          8          0.880218
#          9          0.479902
# dtype: float64

# %%
s.index.is_monotonic_increasing
# Out:
# True

# %%
s.loc[:,[1,3,6]]
# Out:
# letters  numbers
# A        1          0.400376
#          3          0.586291
#          6          0.725093
# B        1          0.095436
#          3          0.458596
#          6          0.266955
# C        1          0.586633
#          3          0.921493
#          6          0.126660
# dtype: float64

# %%
s.loc[pd.IndexSlice[:'B', 5:]]
# Out:
# letters  numbers
# A        5          0.531736
#          6          0.725093
#          7          0.117949
#          8          0.404746
#          9          0.571195
# B        5          0.263086
#          6          0.266955
#          7          0.269640
#          8          0.361145
#          9          0.714692
# dtype: float64

# %%
s.groupby(level=0).sum()
# Out:
# letters
# A    4.999964
# B    3.799329
# C    4.813022
# dtype: float64

# %%
numb=s.groupby(level=1).sum()
numb
# Out:
# numbers
# 0    1.629659
# 1    1.082445
# 2    1.484140
# 3    1.966380
# 4    1.363715
# 5    1.031445
# 6    1.118709
# 7    0.523925
# 8    1.646109
# 9    1.765788
# dtype: float64

# %%
s.unstack().sum(axis=1)
# Out:
# letters
# A    4.999964
# B    3.799329
# C    4.813022
# dtype: float64

# %%
sn = s.swaplevel(0,  1)
sn = sn.sort_index()
sn
# Out:
# numbers  letters
# 0        A          0.739254
#          B          0.161347
#          C          0.729057
# 1        A          0.400376
#          B          0.095436
#          C          0.586633
# 2        A          0.857504
#          B          0.349121
#          C          0.277516
# 3        A          0.586291
#          B          0.458596
#          C          0.921493
# 4        A          0.065819
#          B          0.859310
#          C          0.438586
# 5        A          0.531736
#          B          0.263086
#          C          0.236623
# 6        A          0.725093
#          B          0.266955
#          C          0.126660
# 7        A          0.117949
#          B          0.269640
#          C          0.136335
# 8        A          0.404746
#          B          0.361145
#          C          0.880218
# 9        A          0.571195
#          B          0.714692
#          C          0.479902
# dtype: float64

# %%
df = pd.DataFrame({"x", "y"} :for x,y in range(3) )
df
# Out:
#   File "<ipython-input-215-e720961f2a1f>", line 1
#     df = pd.DataFrame({"x", "y"} :for x,y in range(3) )
#                                  ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
df = pd.DataFrame({"xs":[1,5,2,8,1], "ys":[4,2,1,9,6]})
df
# Out:
#    xs  ys
# 0   1   4
# 1   5   2
# 2   2   1
# 3   8   9
# 4   1   6

# %%
df.plot.scatter("xs", "ys", color = "black", marker = "x")

# %%
df = pd.DataFrame({"productivity":[5,2,3,1,4,5,6,7,8,3,4,8,9],
                   "hours_in"    :[1,9,6,5,3,9,2,9,1,7,4,2,2],
                   "happiness"   :[2,1,3,2,3,1,2,3,1,2,2,1,3],
                   "caffienated" :[0,0,1,1,0,0,0,0,1,1,0,1,0]})
df
# Out:
#     productivity  hours_in  happiness  caffienated
# 0              5         1          2            0
# 1              2         9          1            0
# 2              3         6          3            1
# 3              1         5          2            1
# 4              4         3          3            0
# 5              5         9          1            0
# 6              6         2          2            0
# 7              7         9          3            0
# 8              8         1          1            1
# 9              3         7          2            1
# 10             4         4          2            0
# 11             8         2          1            1
# 12             9         2          3            0

# %%
df.plot.bar()

# %%
df = pd.DataFrame({"revenue":[57,68,63,71,72,90,80,62,59,51,47,52],
                   "advertising":[2.1,1.9,2.7,3.0,3.6,3.2,2.7,2.4,1.8,1.6,1.3,1.9],
                   "month":range(12)
                  })
df
# Out:
#     revenue  advertising  month
# 0        57          2.1      0
# 1        68          1.9      1
# 2        63          2.7      2
# 3        71          3.0      3
# 4        72          3.6      4
# 5        90          3.2      5
# 6        80          2.7      6
# 7        62          2.4      7
# 8        59          1.8      8
# 9        51          1.6      9
# 10       47          1.3     10
# 11       52          1.9     11

# %%
a=df.plot.bar('month', 'revenue', color = 'pink')
df.plot.line("month", "advertising", secondary_y = True,ax=a)
a
